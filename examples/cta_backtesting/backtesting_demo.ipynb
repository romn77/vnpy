# %%
##%%
from vnpy.trader.optimize import OptimizationSetting
from vnpy_ctastrategy.backtesting import BacktestingEngine
from vnpy_ctastrategy.strategies.atr_rsi_strategy import (
    AtrRsiStrategy,
)
from datetime import datetime

# %%
##%%
engine = BacktestingEngine()
engine.set_parameters(
    vt_symbol="IF888.CFFEX",
    interval="1m",
    start=datetime(2019, 1, 1),
    end=datetime(2019, 4, 30),
    rate=0.3/10000,
    slippage=0.2,
    size=300,
    pricetick=0.2,
    capital=1_000_000,
)
engine.add_strategy(AtrRsiStrategy, {})

# %%
##%%
engine.load_data()
engine.run_backtesting()
df = engine.calculate_result()
engine.calculate_statistics()
engine.show_chart()
# Out:
# 2023-09-11 15:16:53.856009	开始加载历史数据
# 2023-09-11 15:16:53.856375	加载进度：# [0%]
# 2023-09-11 15:16:53.927425	加载进度：# [9%]
# 2023-09-11 15:16:53.928062	加载进度：## [18%]
# 2023-09-11 15:16:53.928614	加载进度：### [28%]
# 2023-09-11 15:16:53.929172	加载进度：#### [37%]
# 2023-09-11 15:16:53.929711	加载进度：##### [46%]
# 2023-09-11 15:16:53.930261	加载进度：###### [55%]
# 2023-09-11 15:16:53.930802	加载进度：####### [65%]
# 2023-09-11 15:16:53.931331	加载进度：######## [74%]
# 2023-09-11 15:16:53.931862	加载进度：######### [83%]
# 2023-09-11 15:16:53.932399	加载进度：########## [92%]
# 2023-09-11 15:16:53.932947	历史数据加载完成，数据量：0
# 2023-09-11 15:16:53.933608	策略初始化完成
# 2023-09-11 15:16:53.933623	开始回放历史数据
# 2023-09-11 15:16:53.933632	历史数据回放结束
# 2023-09-11 15:16:53.933677	开始计算逐日盯市盈亏
# 2023-09-11 15:16:53.933685	回测成交记录为空
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/_5/nvb2x0s54nj_02tpvz59kffm0000gn/T/ipykernel_99330/501973437.py in ?()
#       1 ##%%
#       2 engine.load_data()
#       3 engine.run_backtesting()
# ----> 4 df = engine.calculate_result()
#       5 engine.calculate_statistics()
#       6 engine.show_chart()
#
# ~/opt/anaconda3/envs/vnpy_ron/lib/python3.10/site-packages/vnpy_ctastrategy/backtesting.py in ?(self)
#     279         for daily_result in self.daily_results.values():
#     280             for key, value in daily_result.__dict__.items():
#     281                 results[key].append(value)
#     282
# --> 283         self.daily_df = DataFrame.from_dict(results).set_index("date")
#     284
#     285         self.output("逐日盯市盈亏计算完成")
#     286         return self.daily_df
#
# ~/opt/anaconda3/envs/vnpy_ron/lib/python3.10/site-packages/pandas/util/_decorators.py in ?(*args, **kwargs)
#     313                     msg.format(arguments=arguments),
#     314                     FutureWarning,
#     315                     stacklevel=find_stack_level(inspect.currentframe()),
#     316                 )
# --> 317             return func(*args, **kwargs)
#
# ~/opt/anaconda3/envs/vnpy_ron/lib/python3.10/site-packages/pandas/core/frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6000                     if not found:
#    6001                         missing.append(col)
#    6002
#    6003         if missing:
# -> 6004             raise KeyError(f"None of {missing} are in the columns")
#    6005
#    6006         if inplace:
#    6007             frame = self
#
# KeyError: "None of ['date'] are in the columns"

# %%
setting = OptimizationSetting()
setting.set_target("sharpe_ratio")
setting.add_parameter("atr_length", 25, 27, 1)
setting.add_parameter("atr_ma_length", 10, 30, 10)

engine.run_ga_optimization(setting)
# Out:
# 2023-09-11 15:17:19.611324	开始执行遗传算法优化
# 2023-09-11 15:17:19.611575	参数优化空间：9
# 2023-09-11 15:17:19.611597	每代族群总数：100
# 2023-09-11 15:17:19.611607	优良筛选个数：80
# 2023-09-11 15:17:19.611615	迭代次数：30
# 2023-09-11 15:17:19.611631	交叉概率：95%
# 2023-09-11 15:17:19.611641	突变概率：5%
# 2023-09-11 15:17:21.386678	开始加载历史数据
# 2023-09-11 15:17:21.386727	加载进度：# [0%]
# 2023-09-11 15:17:21.534242	加载进度：# [9%]
# 2023-09-11 15:17:21.535553	加载进度：## [18%]
# 2023-09-11 15:17:21.536749	加载进度：### [28%]
# 2023-09-11 15:17:21.537951	加载进度：#### [37%]
# 2023-09-11 15:17:21.539200	加载进度：##### [46%]
# 2023-09-11 15:17:21.547826	加载进度：###### [55%]
# 2023-09-11 15:17:21.549818	加载进度：####### [65%]
# 2023-09-11 15:17:21.551339	加载进度：######## [74%]
# 2023-09-11 15:17:21.552701	加载进度：######### [83%]
# 2023-09-11 15:17:21.553931	加载进度：########## [92%]
# 2023-09-11 15:17:21.555175	历史数据加载完成，数据量：0
# 2023-09-11 15:17:21.556352	策略初始化完成
# 2023-09-11 15:17:21.556372	开始回放历史数据
# 2023-09-11 15:17:21.556386	历史数据回放结束
# 2023-09-11 15:17:21.556393	开始计算逐日盯市盈亏
# 2023-09-11 15:17:21.556399	回测成交记录为空
# 2023-09-11 15:17:21.591475	开始加载历史数据
# 2023-09-11 15:17:21.591510	加载进度：# [0%]
# 2023-09-11 15:17:21.591532	加载进度：# [9%]
# 2023-09-11 15:17:21.591546	加载进度：## [18%]
# 2023-09-11 15:17:21.591557	加载进度：### [28%]
# 2023-09-11 15:17:21.591567	加载进度：#### [37%]
# 2023-09-11 15:17:21.591588	加载进度：##### [46%]
# 2023-09-11 15:17:21.591599	加载进度：###### [55%]
# 2023-09-11 15:17:21.591610	加载进度：####### [65%]
# 2023-09-11 15:17:21.591622	加载进度：######## [74%]
# 2023-09-11 15:17:21.591633	加载进度：######### [83%]
# 2023-09-11 15:17:21.591643	加载进度：########## [92%]
# 2023-09-11 15:17:21.591655	历史数据加载完成，数据量：0
# 2023-09-11 15:17:21.591692	策略初始化完成
# 2023-09-11 15:17:21.591702	开始回放历史数据
# 2023-09-11 15:17:21.591716	历史数据回放结束
# 2023-09-11 15:17:21.591722	开始计算逐日盯市盈亏
# 2023-09-11 15:17:21.591728	回测成交记录为空
# 2023-09-11 15:17:21.598841	开始加载历史数据
# 2023-09-11 15:17:21.598876	加载进度：# [0%]
# 2023-09-11 15:17:21.598898	加载进度：# [9%]
# 2023-09-11 15:17:21.598915	加载进度：## [18%]
# 2023-09-11 15:17:21.598927	加载进度：### [28%]
# 2023-09-11 15:17:21.598938	加载进度：#### [37%]
# 2023-09-11 15:17:21.689501	历史数据加载完成，数据量：0
# 2023-09-11 15:17:21.691144	策略初始化完成
# 2023-09-11 15:17:21.691172	开始回放历史数据
# 2023-09-11 15:17:21.691189	历史数据回放结束
# 2023-09-11 15:17:21.691198	开始计算逐日盯市盈亏
# 2023-09-11 15:17:21.691205	回测成交记录为空
# 2023-09-11 15:17:21.596958	开始加载历史数据
# 2023-09-11 15:17:21.597148	加载进度：# [0%]
# 2023-09-11 15:17:21.697371	加载进度：# [9%]
# 2023-09-11 15:17:21.699461	加载进度：## [18%]
# 2023-09-11 15:17:21.700803	加载进度：### [28%]
# 2023-09-11 15:17:21.702065	加载进度：#### [37%]
# 2023-09-11 15:17:21.703530	加载进度：##### [46%]
# 2023-09-11 15:17:21.704267	加载进度：###### [55%]
# 2023-09-11 15:17:21.706638	加载进度：####### [65%]
# 2023-09-11 15:17:21.707732	加载进度：######## [74%]
# 2023-09-11 15:17:21.711074	加载进度：######### [83%]
# 2023-09-11 15:17:21.712430	加载进度：########## [92%]
# 2023-09-11 15:17:21.713570	历史数据加载完成，数据量：0
# 2023-09-11 15:17:21.714989	策略初始化完成
# 2023-09-11 15:17:21.715006	开始回放历史数据
# 2023-09-11 15:17:21.715015	历史数据回放结束
# 2023-09-11 15:17:21.715019	开始计算逐日盯市盈亏
# 2023-09-11 15:17:21.715023	回测成交记录为空
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/Users/yaoma/opt/anaconda3/envs/vnpy_ron/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/yaoma/opt/anaconda3/envs/vnpy_ron/lib/python3.10/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/Users/yaoma/PycharmProjects/vnpy_ron/vnpy/trader/optimize.py", line 234, in ga_evaluate
#     result: dict = evaluate_func(setting)
#   File "/Users/yaoma/opt/anaconda3/envs/vnpy_ron/lib/python3.10/site-packages/vnpy_ctastrategy/backtesting.py", line 1130, in evaluate
#     engine.calculate_result()
#   File "/Users/yaoma/opt/anaconda3/envs/vnpy_ron/lib/python3.10/site-packages/vnpy_ctastrategy/backtesting.py", line 283, in calculate_result
#     self.daily_df = DataFrame.from_dict(results).set_index("date")
#   File "/Users/yaoma/opt/anaconda3/envs/vnpy_ron/lib/python3.10/site-packages/pandas/util/_decorators.py", line 317, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/yaoma/opt/anaconda3/envs/vnpy_ron/lib/python3.10/site-packages/pandas/core/frame.py", line 6004, in set_index
#     raise KeyError(f"None of {missing} are in the columns")
# KeyError: "None of ['date'] are in the columns"
# """
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 6
#       3 setting.add_parameter("atr_length", 25, 27, 1)
#       4 setting.add_parameter("atr_ma_length", 10, 30, 10)
# ----> 6 engine.run_ga_optimization(setting)
#
# File ~/opt/anaconda3/envs/vnpy_ron/lib/python3.10/site-packages/vnpy_ctastrategy/backtesting.py:557, in BacktestingEngine.run_ga_optimization(self, optimization_setting, output, max_workers)
#     554     return
#     556 evaluate_func: callable = wrap_evaluate(self, optimization_setting.target_name)
# --> 557 results: list = run_ga_optimization(
#     558     evaluate_func,
#     559     optimization_setting,
#     560     get_target_value,
#     561     max_workers=max_workers,
#     562     output=self.output
#     563 )
#     565 if output:
#     566     for result in results:
#
# File ~/PycharmProjects/vnpy_ron/vnpy/trader/optimize.py:199, in run_ga_optimization(evaluate_func, optimization_setting, key_func, max_workers, population_size, ngen_size, output)
#     195 output(f"突变概率：{mutpb:.0%}")
#     197 start: int = perf_counter()
# --> 199 algorithms.eaMuPlusLambda(
#     200     pop,
#     201     toolbox,
#     202     mu,
#     203     lambda_,
#     204     cxpb,
#     205     mutpb,
#     206     ngen,
#     207     verbose=True
#     208 )
#     210 end: int = perf_counter()
#     211 cost: int = int((end - start))
#
# File ~/opt/anaconda3/envs/vnpy_ron/lib/python3.10/site-packages/deap/algorithms.py:301, in eaMuPlusLambda(population, toolbox, mu, lambda_, cxpb, mutpb, ngen, stats, halloffame, verbose)
#     299 # Evaluate the individuals with an invalid fitness
#     300 invalid_ind = [ind for ind in population if not ind.fitness.valid]
# --> 301 fitnesses = toolbox.map(toolbox.evaluate, invalid_ind)
#     302 for ind, fit in zip(invalid_ind, fitnesses):
#     303     ind.fitness.values = fit
#
# File ~/opt/anaconda3/envs/vnpy_ron/lib/python3.10/multiprocessing/pool.py:367, in Pool.map(self, func, iterable, chunksize)
#     362 def map(self, func, iterable, chunksize=None):
#     363     '''
#     364     Apply `func` to each element in `iterable`, collecting the results
#     365     in a list that is returned.
#     366     '''
# --> 367     return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File ~/opt/anaconda3/envs/vnpy_ron/lib/python3.10/multiprocessing/pool.py:774, in ApplyResult.get(self, timeout)
#     772     return self._value
#     773 else:
# --> 774     raise self._value
#
# KeyError: "None of ['date'] are in the columns"

# %%
engine.run_bf_optimization(setting)
# Out:
# 2023-09-11 15:17:25.632487	开始执行穷举算法优化
# 2023-09-11 15:17:25.632577	参数优化空间：9
#   0%|          | 0/9 [00:01<?, ?it/s]
# 2023-09-11 15:17:27.145804	开始加载历史数据
# 2023-09-11 15:17:27.145852	加载进度：# [0%]
# 2023-09-11 15:17:27.257690	加载进度：# [9%]
# 2023-09-11 15:17:27.261774	加载进度：## [18%]
# 2023-09-11 15:17:27.263261	加载进度：### [28%]
# 2023-09-11 15:17:27.267053	加载进度：#### [37%]
# 2023-09-11 15:17:27.269839	加载进度：##### [46%]
# 2023-09-11 15:17:27.271189	加载进度：###### [55%]
# 2023-09-11 15:17:27.273016	加载进度：####### [65%]
# 2023-09-11 15:17:27.274256	加载进度：######## [74%]
# 2023-09-11 15:17:27.275499	加载进度：######### [83%]
# 2023-09-11 15:17:27.278240	加载进度：########## [92%]
# 2023-09-11 15:17:27.280193	历史数据加载完成，数据量：0
# 2023-09-11 15:17:27.281595	策略初始化完成
# 2023-09-11 15:17:27.281618	开始回放历史数据
# 2023-09-11 15:17:27.281633	历史数据回放结束
# 2023-09-11 15:17:27.281642	开始计算逐日盯市盈亏
# 2023-09-11 15:17:27.281648	回测成交记录为空
# 2023-09-11 15:17:27.143741	开始加载历史数据
# 2023-09-11 15:17:27.143785	加载进度：# [0%]
# 2023-09-11 15:17:27.266778	加载进度：# [9%]
# 2023-09-11 15:17:27.268115	加载进度：## [18%]
# 2023-09-11 15:17:27.337122	加载进度：# [9%]
# 2023-09-11 15:17:27.337935	加载进度：## [18%]
# 2023-09-11 15:17:27.339119	加载进度：### [28%]
# 2023-09-11 15:17:27.341057	加载进度：#### [37%]
# 2023-09-11 15:17:27.342441	加载进度：##### [46%]
# 2023-09-11 15:17:27.343374	加载进度：###### [55%]
# 2023-09-11 15:17:27.344246	加载进度：####### [65%]
# 2023-09-11 15:17:27.345137	加载进度：######## [74%]
# 2023-09-11 15:17:27.345775	加载进度：######### [83%]
# 2023-09-11 15:17:27.347003	加载进度：########## [92%]
# 2023-09-11 15:17:27.349028	历史数据加载完成，数据量：0
# 2023-09-11 15:17:27.350563	策略初始化完成
# 2023-09-11 15:17:27.350582	开始回放历史数据
# 2023-09-11 15:17:27.350592	历史数据回放结束
# 2023-09-11 15:17:27.350596	开始计算逐日盯市盈亏
# 2023-09-11 15:17:27.350600	回测成交记录为空
# 2023-09-11 15:17:27.288054	开始加载历史数据
# 2023-09-11 15:17:27.288102	加载进度：# [0%]
# 2023-09-11 15:17:27.352631	加载进度：# [9%]
# 2023-09-11 15:17:27.353709	加载进度：## [18%]
# 2023-09-11 15:17:27.354407	加载进度：### [28%]
# 2023-09-11 15:17:27.356329	加载进度：#### [37%]
# 2023-09-11 15:17:27.357966	加载进度：##### [46%]
# 2023-09-11 15:17:27.359932	加载进度：###### [55%]
# 2023-09-11 15:17:27.361200	加载进度：####### [65%]
# 2023-09-11 15:17:27.362321	加载进度：######## [74%]
# 2023-09-11 15:17:27.363213	加载进度：######### [83%]
# 2023-09-11 15:17:27.364062	加载进度：########## [92%]
# 2023-09-11 15:17:27.365187	历史数据加载完成，数据量：0
# 2023-09-11 15:17:27.366652	策略初始化完成
# 2023-09-11 15:17:27.366691	开始回放历史数据
# 2023-09-11 15:17:27.366732	历史数据回放结束
# 2023-09-11 15:17:27.366740	开始计算逐日盯市盈亏
# 2023-09-11 15:17:27.366744	回测成交记录为空
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/Users/yaoma/opt/anaconda3/envs/vnpy_ron/lib/python3.10/concurrent/futures/process.py", line 246, in _process_worker
#     r = call_item.fn(*call_item.args, **call_item.kwargs)
#   File "/Users/yaoma/opt/anaconda3/envs/vnpy_ron/lib/python3.10/concurrent/futures/process.py", line 205, in _process_chunk
#     return [fn(*args) for args in chunk]
#   File "/Users/yaoma/opt/anaconda3/envs/vnpy_ron/lib/python3.10/concurrent/futures/process.py", line 205, in <listcomp>
#     return [fn(*args) for args in chunk]
#   File "/Users/yaoma/opt/anaconda3/envs/vnpy_ron/lib/python3.10/site-packages/vnpy_ctastrategy/backtesting.py", line 1130, in evaluate
#     engine.calculate_result()
#   File "/Users/yaoma/opt/anaconda3/envs/vnpy_ron/lib/python3.10/site-packages/vnpy_ctastrategy/backtesting.py", line 283, in calculate_result
#     self.daily_df = DataFrame.from_dict(results).set_index("date")
#   File "/Users/yaoma/opt/anaconda3/envs/vnpy_ron/lib/python3.10/site-packages/pandas/util/_decorators.py", line 317, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/yaoma/opt/anaconda3/envs/vnpy_ron/lib/python3.10/site-packages/pandas/core/frame.py", line 6004, in set_index
#     raise KeyError(f"None of {missing} are in the columns")
# KeyError: "None of ['date'] are in the columns"
# """
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 engine.run_bf_optimization(setting)
#
# File ~/opt/anaconda3/envs/vnpy_ron/lib/python3.10/site-packages/vnpy_ctastrategy/backtesting.py:529, in BacktestingEngine.run_bf_optimization(self, optimization_setting, output, max_workers)
#     526     return
#     528 evaluate_func: callable = wrap_evaluate(self, optimization_setting.target_name)
# --> 529 results: list = run_bf_optimization(
#     530     evaluate_func,
#     531     optimization_setting,
#     532     get_target_value,
#     533     max_workers=max_workers,
#     534     output=self.output
#     535 )
#     537 if output:
#     538     for result in results:
#
# File ~/PycharmProjects/vnpy_ron/vnpy/trader/optimize.py:119, in run_bf_optimization(evaluate_func, optimization_setting, key_func, max_workers, output)
#     111 with ProcessPoolExecutor(
#     112     max_workers,
#     113     mp_context=get_context("spawn")
#     114 ) as executor:
#     115     it: Iterable = tqdm(
#     116         executor.map(evaluate_func, settings),
#     117         total=len(settings)
#     118     )
# --> 119     results: List[Tuple] = list(it)
#     120     results.sort(reverse=True, key=key_func)
#     122     end: int = perf_counter()
#
# File ~/opt/anaconda3/envs/vnpy_ron/lib/python3.10/site-packages/tqdm/std.py:1195, in tqdm.__iter__(self)
#    1192 time = self._time
#    1194 try:
# -> 1195     for obj in iterable:
#    1196         yield obj
#    1197         # Update and possibly print the progressbar.
#    1198         # Note: does not call self.update(1) for speed optimisation.
#
# File ~/opt/anaconda3/envs/vnpy_ron/lib/python3.10/concurrent/futures/process.py:575, in _chain_from_iterable_of_lists(iterable)
#     569 def _chain_from_iterable_of_lists(iterable):
#     570     """
#     571     Specialized implementation of itertools.chain.from_iterable.
#     572     Each item in *iterable* should be a list.  This function is
#     573     careful not to keep references to yielded objects.
#     574     """
# --> 575     for element in iterable:
#     576         element.reverse()
#     577         while element:
#
# File ~/opt/anaconda3/envs/vnpy_ron/lib/python3.10/concurrent/futures/_base.py:621, in Executor.map.<locals>.result_iterator()
#     618 while fs:
#     619     # Careful not to keep a reference to the popped future
#     620     if timeout is None:
# --> 621         yield _result_or_cancel(fs.pop())
#     622     else:
#     623         yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#
# File ~/opt/anaconda3/envs/vnpy_ron/lib/python3.10/concurrent/futures/_base.py:319, in _result_or_cancel(***failed resolving arguments***)
#     317 try:
#     318     try:
# --> 319         return fut.result(timeout)
#     320     finally:
#     321         fut.cancel()
#
# File ~/opt/anaconda3/envs/vnpy_ron/lib/python3.10/concurrent/futures/_base.py:458, in Future.result(self, timeout)
#     456     raise CancelledError()
#     457 elif self._state == FINISHED:
# --> 458     return self.__get_result()
#     459 else:
#     460     raise TimeoutError()
#
# File ~/opt/anaconda3/envs/vnpy_ron/lib/python3.10/concurrent/futures/_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# KeyError: "None of ['date'] are in the columns"
